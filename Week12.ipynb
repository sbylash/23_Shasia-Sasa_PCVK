# %% [markdown]
# <a href="https://colab.research.google.com/github/sbylash/23_Shasia-Sasa_PCVK/blob/main/Week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
import matplotlib.pyplot as plt
from google.colab import drive
import numpy as np
from google.colab.patches import cv2_imshow

# %%
path='/content/drive/MyDrive/Images/facedet'

# %%
def display(img,cmap='gray'):
  fig = plt.figure(figsize=(12,10))
  ax = fig.add_subplot(111)
  ax.imshow(img,cmap='gray')

# %%
reeses = cv.imread(f'{path}/reeses_puffs.png',0)
cereals = cv.imread(f'{path}/many_cereals.jpg',0)

# %%
orb = cv.ORB_create()
kp1,des1 = orb.detectAndCompute(reeses,None)
kp2,des2 = orb.detectAndCompute(cereals,None)

bf = cv.BFMatcher(cv.NORM_HAMMING,crossCheck=True)
matches = bf.match(des1,des2)
single_match = matches[0]
single_match.distance
# Out:
# 71.0

# %%
matches = sorted(matches,key=lambda x:x.distance)
reeses_match = cv.drawMatches(reeses,kp1,cereals,kp2,matches[:25],None,flags=2)
display(reeses_match),plt.axis('off')
# Out:
# (None, (-0.5, 1316.5, 559.5, -0.5))

# %%
cascade_wajah = cv.CascadeClassifier(f'/content/drive/MyDrive/Images/haarcascades/haarcascade_frontalface_alt.xml')
presiden = cv.imread(f'{path}/jokowi.jpg', cv.IMREAD_GRAYSCALE)
presiden = cv.cvtColor(presiden, cv.COLOR_GRAY2RGB)
presiden_img = np.copy(presiden)

roi_wajah = cascade_wajah.detectMultiScale(presiden)
for (x,y,w,h) in roi_wajah:
  cv.rectangle(presiden_img,(x,y),(x+w,y+h),(0,255,0),3)
  plt.figure(figsize = (5,5))
  plt.imshow(presiden_img, cmap='gray'),plt.axis('off')

# %% [markdown]
# **TUGAS PRAKTIKUM**

# %%
jokowi = cv.imread(f'{path}/jokowi.jpg')
jokowi = cv.cvtColor(jokowi, cv.COLOR_BGR2RGB)
jokowi_copy = np.copy(jokowi)

roi_wajah = cascade_wajah.detectMultiScale(jokowi_copy)
for (x,y,w,h) in roi_wajah:
  cv.rectangle(jokowi_copy,(x,y),(x+w,y+h),(0,255,0),3)

plt.subplot(121),plt.imshow(jokowi),plt.axis('off')
plt.subplot(122),plt.imshow(jokowi_copy),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x7d22b76e7250>,
#  (-0.5, 872.5, 1049.5, -0.5))

# %%
kartini = cv.imread(f'{path}/kartini.jpg')
kartini_copy = np.copy(kartini)

roi_wajah = cascade_wajah.detectMultiScale(kartini_copy)
for (x,y,w,h) in roi_wajah:
  cv.rectangle(kartini_copy,(x,y),(x+w,y+h),(0,255,0),3)

plt.subplot(121),plt.imshow(kartini),plt.axis('off')
plt.subplot(122),plt.imshow(kartini_copy),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x7d22b758c4f0>,
#  (-0.5, 533.5, 699.5, -0.5))

# %%
cascade_kucing = cv.CascadeClassifier(f'/content/drive/MyDrive/Images/haarcascades/haarcascade_frontalcatface.xml')
kucing = cv.imread(f'{path}/kucing.jpg', cv.IMREAD_GRAYSCALE)
kucing = cv.cvtColor(kucing, cv.COLOR_GRAY2RGB)
kucing_copy = np.copy(kucing)

roi_kucing = cascade_kucing.detectMultiScale(kucing,
                                             scaleFactor=1.1,
                                             minNeighbors=5,
                                             minSize=(30, 30))
filtered_roi_kucing = [roi for roi in roi_kucing if roi[2] > 150 and roi[3] > 150]

for (x,y,w,h) in filtered_roi_kucing:
  cv.rectangle(kucing_copy,(x,y),(x+w,y+h),(0,255,0),3)

plt.figure(figsize = (10,10))
plt.subplot(121),plt.imshow(kucing),plt.axis('off')
plt.subplot(122),plt.imshow(kucing_copy),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x7d22b74c7d30>,
#  (-0.5, 889.5, 533.5, -0.5))

# %%
mask = cv.imread(f'{path}/mask.png',cv.IMREAD_GRAYSCALE)
mask = cv.cvtColor(mask, cv.COLOR_GRAY2RGB)
mask_copy = np.copy(mask)

roi_wajah = cascade_wajah.detectMultiScale(mask_copy)
for (x,y,w,h) in roi_wajah:
  cv.rectangle(mask_copy,(x,y),(x+w,y+h),(0,255,0),3)

plt.figure(figsize = (12,12))
plt.subplot(121),plt.imshow(mask,cmap='gray'),plt.axis('off')
plt.subplot(122),plt.imshow(mask_copy,cmap='gray'),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x7d22b7651210>,
#  (-0.5, 725.5, 479.5, -0.5))

# %%
mjordan = cv.imread(f'{path}/mjordan.jpg',0)
mjordan = cv.cvtColor(mjordan, cv.COLOR_GRAY2RGB)
mjordan_copy = np.copy(mjordan)

roi_wajah = cascade_wajah.detectMultiScale(mjordan_copy)
for (x,y,w,h) in roi_wajah:
  cv.rectangle(mjordan_copy,(x,y),(x+w,y+h),(0,255,0),3)

plt.subplot(121),plt.imshow(mjordan,cmap='gray'),plt.axis('off')
plt.subplot(122),plt.imshow(mjordan_copy,cmap='gray'),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x7d22b74c5a50>,
#  (-0.5, 397.5, 567.5, -0.5))

# %%
solvayconf = cv.imread(f'{path}/solvayconf.jpg')
solvayconf_copy = np.copy(solvayconf)

roi_wajah = cascade_wajah.detectMultiScale(solvayconf_copy)
for (x,y,w,h) in roi_wajah:
  cv.rectangle(solvayconf_copy,(x,y),(x+w,y+h),(0,255,0),3)

plt.figure(figsize = (15,15))
plt.subplot(121),plt.imshow(solvayconf),plt.axis('off')
plt.subplot(122),plt.imshow(solvayconf_copy),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x7d22b761df30>,
#  (-0.5, 1049.5, 759.5, -0.5))

# %%
cascade_mata = cv.CascadeClassifier(f'/content/drive/MyDrive/Images/haarcascades/haarcascade_eye.xml')
jokowi_eyes = np.copy(presiden)

roi_mata = cascade_mata.detectMultiScale(jokowi_eyes)
for (x,y,w,h) in roi_mata:
  cv.rectangle(jokowi_eyes,(x,y),(x+w,y+h),(0,255,0),3)

plt.figure(figsize = (8,8))
plt.subplot(121),plt.imshow(presiden),plt.axis('off')
plt.subplot(122),plt.imshow(jokowi_eyes),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x7d22b6f0a710>,
#  (-0.5, 872.5, 1049.5, -0.5))

# %%
mjordan = cv.imread(f'{path}/mjordan.jpg',0)
mjordan = cv.cvtColor(mjordan, cv.COLOR_GRAY2RGB)
mjordan_copy = np.copy(mjordan)

roi_wajah = cascade_wajah.detectMultiScale(mjordan_copy)
for (x,y,w,h) in roi_wajah:
  roi = mjordan_copy[y:(y+h),x:(x+w)]
  img_blur = cv.medianBlur(roi, 15)

mjordan_copy[y:(y+h),x:(x+w)] = img_blur
plt.subplot(121),plt.imshow(mjordan,cmap='gray'),plt.axis('off')
plt.subplot(122),plt.imshow(mjordan_copy,cmap='gray'), plt.axis('off')
mjordan = cv.imread(f'{path}/mjordan.jpg',0)

# %%
src = cv.imread("/content/drive/MyDrive/KTP/ktp4.png")
gray = cv.cvtColor(src, cv.COLOR_BGR2GRAY)

_, bw = cv.threshold(gray, 127, 255, cv.THRESH_BINARY_INV)

kernel = np.ones((3, 3), np.uint8)

bw = cv.dilate(bw, kernel, iterations=1)
bw = cv.erode(bw, kernel, iterations=1)

contours, _ = cv.findContours(bw, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)

min_area, max_area = 10, 1000
min_aspect_ratio, max_aspect_ratio = 0.2, 10.0

for contour in contours:
    area = cv.contourArea(contour)
    if min_area < area < max_area:
        x, y, w, h = cv.boundingRect(contour)
        aspect_ratio = float(w) / h
        if min_aspect_ratio < aspect_ratio < max_aspect_ratio:
            cv.rectangle(src, (x, y), (x + w, y + h), (0, 0, 255), 1)

cv2_imshow(src)
# Out:
# <PIL.Image.Image image mode=RGB size=493x300>

# %%
nik_crop = src[45:75, 105:350]
plt.imshow(cv.cvtColor(nik_crop, cv.COLOR_BGR2RGB))

# %%
import os
import tqdm
import cv2
import random
import numpy as np
import pickle

# Direktori data training
DATADIR = "dataset/training"
dirs = []

training_data = []
width, height = 100, 100

# Looping direktori data training untuk diambil nama karakternya
for char_name in sorted(os.listdir(DATADIR)):
    dirs.append(char_name)

# Looping semua image data training untuk diubah menjadi array
for char_name in dirs:
    path = os.path.join(DATADIR, char_name)
    class_number = dirs.index(char_name)
    for img in tqdm.tqdm(os.listdir(path)):
        try:
            img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_ANYCOLOR)
            new_array = cv2.resize(img_array, (width, height))
            training_data.append([new_array, class_number])
        except Exception as e:
            pass

random.shuffle(training_data)
X = []
Y = []

for feature, label in training_data:
    X.append(feature)
    Y.append(label)

X = np.array(X).reshape(-1, width, height, 1)

# Tulis ke file pickle
pickle_out = open("X.pickle", "wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("Y.pickle", "wb")
pickle.dump(Y, pickle_out)
pickle_out.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-48-4338dc0d6a5a> in <cell line: 16>()
#      14
#      15 # Looping direktori data training untuk diambil nama karakternya
# ---> 16 for char_name in sorted(os.listdir(DATADIR)):
#      17     dirs.append(char_name)
#      18
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/training'

# %%
import pickle
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense,
ZeroPadding2D
from keras.models import Model
from keras.optimizers import Adam
from keras.utils.np_utils import to_categorical

# Load file pickle
pickle_in = open("X.pickle", "rb")
X = pickle.load(pickle_in)

pickle_in = open("Y.pickle", "rb")
Y = pickle.load(pickle_in)

Y = to_categorical(Y)
X = X / 255.0
width, height = 100, 100

# Input layer
inputs = Input(shape=(width, height, 1))
conv_layer = ZeroPadding2D(padding=(2, 2))(inputs)
conv_layer = Conv2D(16, (5, 5), strides=(1, 1),
activation='relu')(conv_layer)
conv_layer = MaxPooling2D((2, 2))(conv_layer)
conv_layer = Conv2D(32, (3, 3), strides=(1, 1),
activation='relu')(conv_layer)
conv_layer = Conv2D(32, (3, 3), strides=(1, 1),
activation='relu')(conv_layer)
conv_layer = MaxPooling2D((2, 2))(conv_layer)
conv_layer = Conv2D(64, (3, 3), strides=(1, 1),
activation='relu')(conv_layer)

flaten = Flatten()(conv_layer)

fc_layer = Dense(256, activation='relu')(flaten)
fc_layer = Dense(64, activation='relu')(fc_layer)

# Output layer
outputs = Dense(34, activation='softmax')(fc_layer)

adam = Adam(lr=0.0001)
model = Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=adam, loss='categorical_crossentropy',
metrics=['accuracy'])

model.fit(X, Y, epochs=20, verbose=1)

model.save('anpr.model')

# %%
conv_layer = ZeroPadding2D(padding=(2, 2))(inputs)
conv_layer = Conv2D(16, (5, 5), strides=(1, 1),
activation='relu')(conv_layer)
conv_layer = MaxPooling2D((2, 2))(conv_layer)
conv_layer = Conv2D(32, (3, 3), strides=(1, 1),
activation='relu')(conv_layer)
conv_layer = Conv2D(32, (3, 3), strides=(1, 1),
activation='relu')(conv_layer)
conv_layer = MaxPooling2D((2, 2))(conv_layer)
conv_layer = Conv2D(64, (3, 3), strides=(1, 1),
activation='relu')(conv_layer)

# %%
import os
import cv2
import tensorflow as tf
import numpy as np

data_dir_training = "dataset/training-bak"
data_dir_testing = "dataset/testing"
dirs = []
width, height = 100, 100

model = tf.keras.models.load_model("anpr.model")

for char_name in sorted(os.listdir(data_dir_training)):
  dirs.append(char_name)

for car in sorted(os.listdir(data_dir_testing)):
  temp = ""
  for char_img in sorted(os.listdir(os.path.join(data_dir_testing, car))):
    img_array = cv2.imread(os.path.join(data_dir_testing, car, char_img), cv2.IMREAD_ANYCOLOR)
    new_array = cv2.resize(img_array, (width, height))
    new_array = np.array(new_array).reshape(-1, width, height, 1)

    new_array = new_array / 255.0

    prediction = model.predict(new_array)
    temp += dirs[np.argmax(prediction[0])]
  print("folder name: {} no: {}".format(car, temp))

# %% [markdown]
# **TUGAS**

# %%
src = cv.imread("/content/drive/MyDrive/KTP/ktp.png")
gray = cv.cvtColor(src, cv.COLOR_BGR2GRAY)

_, bw = cv.threshold(gray, 127, 255, cv.THRESH_BINARY_INV)

kernel = np.ones((3, 3), np.uint8)

bw = cv.dilate(bw, kernel, iterations=1)
bw = cv.erode(bw, kernel, iterations=1)

contours, _ = cv.findContours(bw, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)

min_area, max_area = 10, 1000
min_aspect_ratio, max_aspect_ratio = 0.2, 10.0

for contour in contours:
    area = cv.contourArea(contour)
    if min_area < area < max_area:
        x, y, w, h = cv.boundingRect(contour)
        aspect_ratio = float(w) / h
        if min_aspect_ratio < aspect_ratio < max_aspect_ratio:
            cv.rectangle(src, (x, y), (x + w, y + h), (0, 0, 255), 2)

cv2_imshow(src)

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/Images/haarcascades/haarcascade_frontalcatface.xml')
cat = cv.imread('/content/drive/MyDrive/Images/Object Detection/cat2_templatejpg.jpg',0)
roi_wajah = cascade_wajah.detectMultiScale(cat)
for(x,y,w,h) in roi_wajah:
 cv.rectangle(cat,(x,y),(x+w,y+h),(255,255,255),3)
plt.figure(figsize = (10,10))
plt.imshow(cat, cmap='gray')
